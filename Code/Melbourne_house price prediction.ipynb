# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from Tools.scripts.generate_re_casefix import alpha
from scipy.stats import logistic
import joblib

# %%
df = pd.read_csv("C:\\Users\\hp\\PyCharmMiscProject\\git\\melbourne-house-price-predictions\\Data\\Melbourne_housing_FULL.csv")

# %%
df
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
df.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.drop(['Address','Date','Postcode','YearBuilt','Lattitude','Longtitude',],axis='columns',inplace=True)

# %%
df
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
fills_to_zero = ['Car','Bathroom','Bedroom2','Distance','Propertycount']
df[fills_to_zero] = df[fills_to_zero].fillna(0)

# %%
df['Landsize'] = df['Landsize'].fillna(df['Landsize'].mean())
df['BuildingArea'] = df['BuildingArea'].fillna(df['BuildingArea'].mean())

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Price            7610
# Method              0
# SellerG             0
# Distance            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# CouncilArea         3
# Regionname          3
# Propertycount       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df  = pd.get_dummies(df,drop_first=True)

# %%
x = df.drop(['Price'],axis = "columns")
y = df.Price

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
len(x_train),len(x_test)
# Out:
# (21795, 5449)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier

# %%
linear_model = LinearRegression()
RF_model = RandomForestClassifier()

# %%
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear_model.score(x_test,y_test)
# Out:
# 0.6725908367719278

# %%
linear_model.score(x_train,y_train)
# Out:
# 0.6800937261284832

# %%
from sklearn import linear_model

# %%
clf = linear_model.Lasso(alpha=0.1)

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=1.0)

# %%
ridge_model.fit(x_train,y_train)
# Out:
# Ridge()

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.6745409030815537

# %%
ridge_model.score(x_train,y_train)
# Out:
# 0.6795565487688043

# %%
joblib.dump(clf,"melbourne_house_price_prediction_linear_model.pkl")
# Out:
# ['melbourne_house_price_prediction_linear_model.pkl']

# %%
joblib.dump(ridge_model,"melbourne_house_price_prediction_model.pkl")
# Out:
# ['melbourne_house_price_prediction_model.pkl']
